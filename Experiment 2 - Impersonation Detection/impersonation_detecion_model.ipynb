# %%
import pandas as pd
import numpy as np
from autogluon.tabular import TabularPredictor
import seaborn as sns
import matplotlib.pyplot as plt

# %%
naive_training = pd.read_csv('naive_training.csv')
gaussian_copula_training = pd.read_csv('gaussian_copula_training.csv')
gan_training = pd.read_csv('gan_training.csv')
vae_training = pd.read_csv('vae_training.csv')

naive_testing = pd.read_csv('naive_testing.csv')
gaussian_copula_testing = pd.read_csv('gaussian_copula_testing.csv')
gan_testing = pd.read_csv('gan_testing.csv')
vae_testing = pd.read_csv('vae_testing.csv')

combined_testing = pd.concat([naive_testing, gaussian_copula_testing, gan_testing, vae_testing])
print(len(combined_testing))

# each testing csv has the same genuine rows in them, dropping duplicates.
combined_testing.drop_duplicates(inplace=True)

print(len(combined_testing))
# Out:
# 11000
# 8000

# %%
combined_testing['label'].hist()
# Out:
# <Axes: >

# %%
import itertools

attack_types = ['gan', 'gaussian', 'vae', 'naive']
adversarial_techniques_permutations = []

# Generate all permutations of attack_types in different sizes
for size in range(1, len(attack_types) + 1):
    for permutation in itertools.permutations(attack_types, size):
        permutation = list(permutation)
        permutation.sort()
        if permutation not in adversarial_techniques_permutations:
            adversarial_techniques_permutations.append(permutation)
adversarial_techniques_permutations
# Out:
# [['gan'],
#  ['gaussian'],
#  ['vae'],
#  ['naive'],
#  ['gan', 'gaussian'],
#  ['gan', 'vae'],
#  ['gan', 'naive'],
#  ['gaussian', 'vae'],
#  ['gaussian', 'naive'],
#  ['naive', 'vae'],
#  ['gan', 'gaussian', 'vae'],
#  ['gan', 'gaussian', 'naive'],
#  ['gan', 'naive', 'vae'],
#  ['gaussian', 'naive', 'vae'],
#  ['gan', 'gaussian', 'naive', 'vae']]

# %%
results = pd.DataFrame(columns=['techniques', 'roc_auc', 'f1', 'precision', 'recall'])

for attack_types in adversarial_techniques_permutations:
    variable_training_df = pd.DataFrame()
    techniques_string = ''
    print(attack_types)
    if 'naive' in attack_types:
        variable_training_df = pd.concat([variable_training_df, naive_training])
    
    if 'gaussian' in attack_types:
        variable_training_df = pd.concat([variable_training_df, gaussian_copula_training])

    if 'gan' in attack_types:
        variable_training_df = pd.concat([variable_training_df, gan_training])

    if 'vae' in attack_types:
        variable_training_df = pd.concat([variable_training_df, vae_training])
    
    print(len(variable_training_df))
    
    
    # predictor = TabularPredictor(label='label').fit(training_dataset, num_gpus=1, presets='good_quality')
    # y_pred = predictor.predict(testing_dataset)
    # y_pred_proba = predictor.predict_proba(testing_dataset)
    # single_result = predictor.evaluate(testing_dataset)
    
    # new_results = {'techniques':techniques_string, 'roc_auc':single_result['roc_auc'], 'f1':single_result['f1'], 'precision':single_result['precision'], 'recall':single_result['recall']}
    # results.loc[len(results)] = (new_results)
# Out:
# ['gan']
# 9000
# ['gaussian']
# 9000
# ['vae']
# 9000
# ['naive']
# 10000
# ['gan', 'gaussian']
# 18000
# ['gan', 'vae']
# 18000
# ['gan', 'naive']
# 19000
# ['gaussian', 'vae']
# 18000
# ['gaussian', 'naive']
# 19000
# ['naive', 'vae']
# 19000
# ['gan', 'gaussian', 'vae']
# 27000
# ['gan', 'gaussian', 'naive']
# 28000
# ['gan', 'naive', 'vae']
# 28000
# ['gaussian', 'naive', 'vae']
# 28000
# ['gan', 'gaussian', 'naive', 'vae']
# 37000

# %%
hardening_results
# Out:
#                 techniques   roc_auc        f1  precision   recall
# 0                      gan  0.924870  0.810468   0.685576  0.99100
# 1                 gaussian  0.714005  0.726593   0.571818  0.99625
# 2                      vae  0.892772  0.807881   0.682712  0.98925
# 3                    naive  0.945291  0.806368   0.687467  0.97500
# 4             gan_gaussian  0.927942  0.820731   0.702026  0.98775
# 5                  gan_vae  0.950445  0.892626   0.818163  0.98200
# 6                gan_naive  0.971008  0.911458   0.865558  0.96250
# 7             gaussian_vae  0.945394  0.883298   0.801958  0.98300
# 8           gaussian_naive  0.963643  0.888145   0.825005  0.96175
# 9                naive_vae  0.956264  0.879807   0.813415  0.95800
# 10        gan_gaussian_vae  0.956324  0.884864   0.808607  0.97700
# 11      gan_gaussian_naive  0.964846  0.905467   0.866377  0.94825
# 12           gan_naive_vae  0.970145  0.913486   0.876062  0.95425
# 13      gaussian_naive_vae  0.972215  0.917143   0.893340  0.94225
# 14  gan_gaussian_naive_vae  0.971872  0.917514   0.899976  0.93575

# %%
plt.xticks(rotation=90)
sns.lineplot(data=pd.melt(hardening_results, ['techniques']), x='techniques', y='value', style="variable", hue='variable', palette="pastel", linewidth=2.5)
# Out:
# <Axes: xlabel='techniques', ylabel='value'>

# %% [markdown]
# With these metrics, we can gain a deeper understanding of your model's performance.
#
#
# Overall Performance
#
#
#
# ROC-AUC: 0.972687 (excellent) - This indicates that your model is highly effective in distinguishing between positive and negative classes.
#
# F1 Score: 0.918464 (very good) - Your model balances precision and recall well, indicating it's accurate both in identifying actual positives and minimizing false positives.
#
#
# Precision-Recall Tradeoff
#
#
#
# Precision: 0.896076 (good) - While not as high as the F1 score, your model still does a great job of correctly identifying positive instances.
#
# Recall: 0.94200 (excellent) - Your model excels at catching actual positives, which is crucial for authentication purposes.
#
#
# Interpretation
#
#
# These metrics collectively suggest that your anomaly detection model performs exceptionally well in:
#
#
#
# Identifying genuine users (recall: 0.94200)
#
# Correctly classifying positive instances (precision: 0.896076)
#
# Balancing precision and recall with an F1 score of 0.918464
#
# Distinguishing between actual positives and negatives with a high ROC-AUC score of 0.972687
#
#
# The only minor area for improvement is the slight discrepancy in the precision-recall tradeoff, where the F1 score is higher than precision. However, this difference is not significant enough to be concerned about.
#
#
# Overall, your model appears to be very effective at authentication tasks!

# %%
# testing_dataset = pd.concat([test_data[:4000], bad_testing['naive'], bad_testing['gaussian'], bad_testing['vae'], bad_testing['gan']])
# hardening_results = pd.DataFrame(columns=['techniques', 'roc_auc', 'f1', 'precision', 'recall'])

# adversarial_techniques_permutations = [['gan', 'gaussian', 'naive', 'vae']]
# for techniques in adversarial_techniques_permutations:
#     training_dataset = train_data[:4000]
#     techniques_string = ''
#     for individual_technique in techniques:
#         techniques_string += f'_{individual_technique}' if len(techniques_string) > 0 else individual_technique
#         print(individual_technique)
#         training_dataset = pd.concat([training_dataset, bad_training[individual_technique]])
#         print(len(training_dataset))
    
#     predictor = TabularPredictor(label='label', eval_metric='f1').fit(training_dataset, num_gpus=1, presets='good_quality', time_limit=3600)
#     y_pred = predictor.predict(testing_dataset)
#     y_pred_proba = predictor.predict_proba(testing_dataset)
#     results = predictor.evaluate(testing_dataset)
    
#     new_results = {'techniques':techniques_string, 'roc_auc':results['roc_auc'], 'f1':results['f1'], 'precision':results['precision'], 'recall':results['recall']}
#     hardening_results.loc[len(hardening_results)] = (new_results)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241101_083000"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.11.10
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #48-Ubuntu SMP PREEMPT_DYNAMIC Fri Sep 27 14:04:52 UTC 2024
# CPU Count:          28
# Memory Avail:       18.10 GB / 30.81 GB (58.7%)
# Disk Space Avail:   147.57 GB / 341.37 GB (43.2%)
# ===================================================
# Presets specified: ['good_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# gan
# 5000
# gaussian
# 6000
# naive
# 7000
# vae
# 8000
# 2024-11-01 19:30:01,975	INFO worker.py:1743 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 		Context path: "AutogluonModels/ag-20241101_083000/ds_sub_fit/sub_fit_ho"
# (_dystack pid=283888) Running DyStack sub-fit ...
# (_dystack pid=283888) Beginning AutoGluon training ... Time limit = 898s
# (_dystack pid=283888) AutoGluon will save models to "AutogluonModels/ag-20241101_083000/ds_sub_fit/sub_fit_ho"
# (_dystack pid=283888) Train Data Rows:    7111
# (_dystack pid=283888) Train Data Columns: 7
# (_dystack pid=283888) Label Column:       label
# (_dystack pid=283888) Problem Type:       binary
# (_dystack pid=283888) Preprocessing data ...
# (_dystack pid=283888) Selected class <--> label mapping:  class 1 = good, class 0 = bad
# (_dystack pid=283888) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (good) vs negative (bad) class.
# (_dystack pid=283888) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=283888) Using Feature Generators to preprocess the data ...
# (_dystack pid=283888) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=283888) 	Available Memory:                    16369.74 MB
# (_dystack pid=283888) 	Train Data (Original)  Memory Usage: 0.38 MB (0.0% of available memory)
# (_dystack pid=283888) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=283888) 	Stage 1 Generators:
# (_dystack pid=283888) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=283888) 	Stage 2 Generators:
# (_dystack pid=283888) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=283888) 	Stage 3 Generators:
# (_dystack pid=283888) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=283888) 	Stage 4 Generators:
# (_dystack pid=283888) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=283888) 	Stage 5 Generators:
# (_dystack pid=283888) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=283888) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=283888) 		('float', []) : 7 | ['Feature 0', 'Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', ...]
# (_dystack pid=283888) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=283888) 		('float', []) : 7 | ['Feature 0', 'Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', ...]
# (_dystack pid=283888) 	0.0s = Fit runtime
# (_dystack pid=283888) 	7 features in original data used to generate 7 features in processed data.
# (_dystack pid=283888) 	Train Data (Processed) Memory Usage: 0.38 MB (0.0% of available memory)
# (_dystack pid=283888) Data preprocessing and feature engineering runtime = 0.01s ...
# (_dystack pid=283888) AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# (_dystack pid=283888) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=283888) User-specified model hyperparameters to be fit:
# (_dystack pid=283888) {
# (_dystack pid=283888) 	'NN_TORCH': {},
# (_dystack pid=283888) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=283888) 	'CAT': {},
# (_dystack pid=283888) 	'XGB': {},
# (_dystack pid=283888) 	'FASTAI': {},
# (_dystack pid=283888) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=283888) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=283888) }
# (_dystack pid=283888) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=283888) Fitting 11 L1 models ...
# (_dystack pid=283888) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 598.22s of the 897.56s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.03%)
# (_ray_fit pid=285488) [1000]	valid_set's binary_logloss: 0.320874	valid_set's f1: 0.875664
# (_dystack pid=283888) 	0.8872	 = Validation score   (f1)
# (_dystack pid=283888) 	6.0s	 = Training   runtime
# (_dystack pid=283888) 	0.16s	 = Validation runtime
# (_dystack pid=283888) Fitting model: LightGBM_BAG_L1 ... Training model for up to 591.22s of the 890.56s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.02%)
# (_dystack pid=283888) 	0.9236	 = Validation score   (f1)
# (_dystack pid=283888) 	1.37s	 = Training   runtime
# (_dystack pid=283888) 	0.03s	 = Validation runtime
# (_dystack pid=283888) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 589.07s of the 888.4s of remaining time.
# (_dystack pid=283888) 	0.8811	 = Validation score   (f1)
# (_dystack pid=283888) 	0.36s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 588.54s of the 887.88s of remaining time.
# (_dystack pid=283888) 	0.8824	 = Validation score   (f1)
# (_dystack pid=283888) 	0.35s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: CatBoost_BAG_L1 ... Training model for up to 588.04s of the 887.38s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.03%)
# (_dystack pid=283888) 	0.9209	 = Validation score   (f1)
# (_dystack pid=283888) 	14.38s	 = Training   runtime
# (_dystack pid=283888) 	0.01s	 = Validation runtime
# (_dystack pid=283888) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 572.92s of the 872.26s of remaining time.
# (_dystack pid=283888) 	0.8079	 = Validation score   (f1)
# (_dystack pid=283888) 	0.31s	 = Training   runtime
# (_dystack pid=283888) 	0.09s	 = Validation runtime
# (_dystack pid=283888) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 572.46s of the 871.79s of remaining time.
# (_dystack pid=283888) 	0.8073	 = Validation score   (f1)
# (_dystack pid=283888) 	0.31s	 = Training   runtime
# (_dystack pid=283888) 	0.09s	 = Validation runtime
# (_dystack pid=283888) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 572.0s of the 871.33s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.03%)
# (_dystack pid=283888) 	0.7519	 = Validation score   (f1)
# (_dystack pid=283888) 	15.79s	 = Training   runtime
# (_dystack pid=283888) 	0.04s	 = Validation runtime
# (_dystack pid=283888) Fitting model: XGBoost_BAG_L1 ... Training model for up to 555.49s of the 854.82s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.04%)
# (_dystack pid=283888) 	0.9174	 = Validation score   (f1)
# (_dystack pid=283888) 	7.25s	 = Training   runtime
# (_dystack pid=283888) 	0.02s	 = Validation runtime
# (_dystack pid=283888) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 547.46s of the 846.8s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=28, gpus=0, memory=0.02%)
# (_dystack pid=283888) 	0.8455	 = Validation score   (f1)
# (_dystack pid=283888) 	133.6s	 = Training   runtime
# (_dystack pid=283888) 	0.04s	 = Validation runtime
# (_dystack pid=283888) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 413.11s of the 712.45s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.05%)
# (_ray_fit pid=301237) [1000]	valid_set's binary_logloss: 0.395939	valid_set's f1: 0.918979 [repeated 11x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_dystack pid=283888) 	0.9262	 = Validation score   (f1)
# (_dystack pid=283888) 	2.72s	 = Training   runtime
# (_dystack pid=283888) 	0.11s	 = Validation runtime
# (_dystack pid=283888) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 708.9s of remaining time.
# (_dystack pid=283888) 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# (_dystack pid=283888) 	0.9262	 = Validation score   (f1)
# (_dystack pid=283888) 	0.34s	 = Training   runtime
# (_dystack pid=283888) 	0.0s	 = Validation runtime
# (_dystack pid=283888) Fitting 11 L2 models ...
# (_dystack pid=283888) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 708.52s of the 708.52s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.05%)
# (_dystack pid=283888) 	0.9299	 = Validation score   (f1)
# (_dystack pid=283888) 	1.11s	 = Training   runtime
# (_dystack pid=283888) 	0.02s	 = Validation runtime
# (_dystack pid=283888) Fitting model: LightGBM_BAG_L2 ... Training model for up to 706.62s of the 706.62s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.05%)
# (_dystack pid=283888) 	0.9302	 = Validation score   (f1)
# (_dystack pid=283888) 	1.07s	 = Training   runtime
# (_dystack pid=283888) 	0.01s	 = Validation runtime
# (_dystack pid=283888) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 704.75s of the 704.74s of remaining time.
# (_dystack pid=283888) 	0.9274	 = Validation score   (f1)
# (_dystack pid=283888) 	0.38s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 704.22s of the 704.21s of remaining time.
# (_dystack pid=283888) 	0.9262	 = Validation score   (f1)
# (_dystack pid=283888) 	0.36s	 = Training   runtime
# (_dystack pid=283888) 	0.09s	 = Validation runtime
# (_dystack pid=283888) Fitting model: CatBoost_BAG_L2 ... Training model for up to 703.7s of the 703.7s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.07%)
# (_dystack pid=283888) 	0.9261	 = Validation score   (f1)
# (_dystack pid=283888) 	6.09s	 = Training   runtime
# (_dystack pid=283888) 	0.01s	 = Validation runtime
# (_dystack pid=283888) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 696.89s of the 696.89s of remaining time.
# (_dystack pid=283888) 	0.929	 = Validation score   (f1)
# (_dystack pid=283888) 	0.33s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 696.38s of the 696.38s of remaining time.
# (_dystack pid=283888) 	0.9263	 = Validation score   (f1)
# (_dystack pid=283888) 	0.33s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 695.89s of the 695.89s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.05%)
# (_dystack pid=283888) 	0.9305	 = Validation score   (f1)
# (_dystack pid=283888) 	14.81s	 = Training   runtime
# (_dystack pid=283888) 	0.05s	 = Validation runtime
# (_dystack pid=283888) Fitting model: XGBoost_BAG_L2 ... Training model for up to 680.34s of the 680.34s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.08%)
# (_dystack pid=283888) 	0.9278	 = Validation score   (f1)
# (_dystack pid=283888) 	5.69s	 = Training   runtime
# (_dystack pid=283888) 	0.03s	 = Validation runtime
# (_dystack pid=283888) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 673.91s of the 673.91s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=28, gpus=0, memory=0.03%)
# (_dystack pid=283888) 	0.9288	 = Validation score   (f1)
# (_dystack pid=283888) 	48.33s	 = Training   runtime
# (_dystack pid=283888) 	0.05s	 = Validation runtime
# (_dystack pid=283888) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 624.82s of the 624.82s of remaining time.
# (_dystack pid=283888) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.10%)
# (_dystack pid=283888) 	0.9293	 = Validation score   (f1)
# (_dystack pid=283888) 	2.52s	 = Training   runtime
# (_dystack pid=283888) 	0.03s	 = Validation runtime
# (_dystack pid=283888) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 621.47s of remaining time.
# (_dystack pid=283888) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.957, 'XGBoost_BAG_L2': 0.043}
# (_dystack pid=283888) 	0.9305	 = Validation score   (f1)
# (_dystack pid=283888) 	0.63s	 = Training   runtime
# (_dystack pid=283888) 	0.0s	 = Validation runtime
# (_dystack pid=283888) AutoGluon training complete, total runtime = 276.77s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1638.8 rows/s (889 batch size)
# (_dystack pid=283888) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=283888) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=283888) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=283888) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=283888) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=283888) 	1.49s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=283888) 	0.41s	 = Training   runtime
# (_dystack pid=283888) Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.36s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.35s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=283888) 	2.0s	 = Training   runtime
# (_dystack pid=283888) Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.31s	 = Training   runtime
# (_dystack pid=283888) 	0.09s	 = Validation runtime
# (_dystack pid=283888) Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.31s	 = Training   runtime
# (_dystack pid=283888) 	0.09s	 = Validation runtime
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=283888) No improvement since epoch 0: early stopping
# (_dystack pid=283888) 	3.78s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=283888) 	0.27s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# (_dystack pid=283888) 	16.81s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L1 models ...
# (_dystack pid=283888) Fitting model: LightGBMLarge_BAG_L1_FULL ...
# (_dystack pid=283888) 	1.78s	 = Training   runtime
# (_dystack pid=283888) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# (_dystack pid=283888) 	0.34s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: LightGBMXT_BAG_L2_FULL ...
# (_dystack pid=283888) 	0.26s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: LightGBM_BAG_L2_FULL ...
# (_dystack pid=283888) 	0.21s	 = Training   runtime
# (_dystack pid=283888) Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.38s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.36s	 = Training   runtime
# (_dystack pid=283888) 	0.09s	 = Validation runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: CatBoost_BAG_L2_FULL ...
# (_dystack pid=283888) 	0.3s	 = Training   runtime
# (_dystack pid=283888) Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.33s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	0.33s	 = Training   runtime
# (_dystack pid=283888) 	0.1s	 = Validation runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# (_dystack pid=283888) 	Stopping at the best epoch learned earlier - 10.
# (_dystack pid=283888) 	1.03s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: XGBoost_BAG_L2_FULL ...
# (_dystack pid=283888) 	0.14s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# (_dystack pid=283888) 	1.92s	 = Training   runtime
# (_dystack pid=283888) Fitting 1 L2 models ...
# (_dystack pid=283888) Fitting model: LightGBMLarge_BAG_L2_FULL ...
# (_dystack pid=283888) 	0.86s	 = Training   runtime
# (_dystack pid=283888) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=283888) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.957, 'XGBoost_BAG_L2': 0.043}
# (_dystack pid=283888) 	0.63s	 = Training   runtime
# (_dystack pid=283888) Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# (_dystack pid=283888) Refit complete, total runtime = 33.14s ... Best model: "WeightedEnsemble_L3_FULL"
# (_dystack pid=283888) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241101_083000/ds_sub_fit/sub_fit_ho")
# (_dystack pid=283888) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                            model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     ExtraTreesGini_BAG_L2_FULL       0.938998   0.928962          f1        0.269110            NaN  28.209039                 0.043474                0.103952           0.333009            2       True         18
# 1     ExtraTreesEntr_BAG_L2_FULL       0.936819   0.926296          f1        0.269913            NaN  28.202489                 0.044277                0.102363           0.326460            2       True         19
# 2      LightGBMLarge_BAG_L2_FULL       0.935236   0.929307          f1        0.231472            NaN  28.740434                 0.005836                     NaN           0.864404            2       True         23
# 3    NeuralNetFastAI_BAG_L2_FULL       0.934924   0.930506          f1        0.235453            NaN  28.909781                 0.009817                     NaN           1.033752            2       True         20
# 4       WeightedEnsemble_L3_FULL       0.934924   0.930525          f1        0.241992            NaN  29.674622                 0.000750                     NaN           0.629541            3       True         24
# 5   RandomForestEntr_BAG_L2_FULL       0.934354   0.926169          f1        0.266559            NaN  28.234196                 0.040923                0.094950           0.358167            2       True         16
# 6   RandomForestGini_BAG_L2_FULL       0.934354   0.927409          f1        0.267789            NaN  28.253380                 0.042153                0.097610           0.377351            2       True         15
# 7           CatBoost_BAG_L2_FULL       0.933479   0.926108          f1        0.227429            NaN  28.179291                 0.001793                     NaN           0.303262            2       True         17
# 8           LightGBM_BAG_L2_FULL       0.933041   0.930156          f1        0.226914            NaN  28.090421                 0.001278                     NaN           0.214391            2       True         14
# 9            XGBoost_BAG_L2_FULL       0.932166   0.927838          f1        0.231426            NaN  28.011329                 0.005790                     NaN           0.135300            2       True         21
# 10          CatBoost_BAG_L1_FULL       0.931868   0.920889          f1        0.002690            NaN   2.002683                 0.002690                     NaN           2.002683            1       True          5
# 11        LightGBMXT_BAG_L2_FULL       0.931447   0.929896          f1        0.227287            NaN  28.132174                 0.001651                     NaN           0.256144            2       True         13
# 12    NeuralNetTorch_BAG_L2_FULL       0.931148   0.928824          f1        0.231755            NaN  29.793098                 0.006119                     NaN           1.917068            2       True         22
# 13     LightGBMLarge_BAG_L1_FULL       0.926293   0.926150          f1        0.010284            NaN   1.777639                 0.010284                     NaN           1.777639            1       True         11
# 14      WeightedEnsemble_L2_FULL       0.926293   0.926150          f1        0.011023            NaN   2.119925                 0.000739                     NaN           0.342286            2       True         12
# 15          LightGBM_BAG_L1_FULL       0.926130   0.923563          f1        0.002950            NaN   0.405810                 0.002950                     NaN           0.405810            1       True          2
# 16           XGBoost_BAG_L1_FULL       0.923077   0.917388          f1        0.007591            NaN   0.273553                 0.007591                     NaN           0.273553            1       True          9
# 17        LightGBMXT_BAG_L1_FULL       0.892973   0.887151          f1        0.008834            NaN   1.490704                 0.008834                     NaN           1.490704            1       True          1
# 18  RandomForestGini_BAG_L1_FULL       0.886994   0.881134          f1        0.048681       0.103832   0.361634                 0.048681                0.103832           0.361634            1       True          3
# 19  RandomForestEntr_BAG_L1_FULL       0.882540   0.882408          f1        0.044299       0.098824   0.349304                 0.044299                0.098824           0.349304            1       True          4
# 20    NeuralNetTorch_BAG_L1_FULL       0.844262   0.845503          f1        0.005141            NaN  16.808488                 0.005141                     NaN          16.808488            1       True         10
# 21    ExtraTreesGini_BAG_L1_FULL       0.802789   0.807882          f1        0.041711       0.093112   0.312752                 0.041711                0.093112           0.312752            1       True          6
# 22    ExtraTreesEntr_BAG_L1_FULL       0.800000   0.807346          f1        0.042549       0.094162   0.310714                 0.042549                0.094162           0.310714            1       True          7
# 23   NeuralNetFastAI_BAG_L1_FULL       0.641899   0.751904          f1        0.010907            NaN   3.782750                 0.010907                     NaN           3.782750            1       True          8
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	314s	 = DyStack   runtime |	3286s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 3286s
# AutoGluon will save models to "AutogluonModels/ag-20241101_083000"
# Train Data Rows:    8000
# Train Data Columns: 7
# Label Column:       label
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = good, class 0 = bad
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (good) vs negative (bad) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    24852.67 MB
# 	Train Data (Original)  Memory Usage: 0.43 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 7 | ['Feature 0', 'Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 7 | ['Feature 0', 'Feature 1', 'Feature 2', 'Feature 3', 'Feature 4', ...]
# 	0.0s = Fit runtime
# 	7 features in original data used to generate 7 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.43 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.02s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2190.43s of the 3286.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.02%)
# 	0.9012	 = Validation score   (f1)
# 	8.23s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 2181.26s of the 3277.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.02%)
# 	0.9251	 = Validation score   (f1)
# 	1.6s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 2178.87s of the 3274.9s of remaining time.
# 	0.8842	 = Validation score   (f1)
# 	0.36s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 2178.36s of the 3274.4s of remaining time.
# 	0.8821	 = Validation score   (f1)
# 	0.31s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 2177.92s of the 3273.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.02%)
# 	0.9222	 = Validation score   (f1)
# 	16.62s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 2160.58s of the 3256.62s of remaining time.
# 	0.8041	 = Validation score   (f1)
# 	0.28s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 2160.18s of the 3256.21s of remaining time.
# 	0.8056	 = Validation score   (f1)
# 	0.28s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2159.77s of the 3255.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.02%)
# 	0.7529	 = Validation score   (f1)
# 	17.44s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2141.6s of the 3237.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.03%)
# 	0.9195	 = Validation score   (f1)
# 	7.28s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 2133.6s of the 3229.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=28, gpus=0, memory=0.01%)
# 	0.8459	 = Validation score   (f1)
# 	123.98s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 2008.88s of the 3104.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.03%)
# 	0.9265	 = Validation score   (f1)
# 	3.57s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 3100.52s of remaining time.
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.9265	 = Validation score   (f1)
# 	0.3s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 11 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 3100.22s of the 3100.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.03%)
# 	0.9307	 = Validation score   (f1)
# 	0.91s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 3098.55s of the 3098.54s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.04%)
# 	0.9281	 = Validation score   (f1)
# 	1.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 3096.51s of the 3096.5s of remaining time.
# 	0.927	 = Validation score   (f1)
# 	0.36s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 3096.02s of the 3096.02s of remaining time.
# 	0.928	 = Validation score   (f1)
# 	0.34s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3095.56s of the 3095.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.05%)
# 	0.9273	 = Validation score   (f1)
# 	6.08s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 3088.77s of the 3088.77s of remaining time.
# 	0.9278	 = Validation score   (f1)
# 	0.3s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 3088.34s of the 3088.33s of remaining time.
# 	0.9284	 = Validation score   (f1)
# 	0.29s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 3087.91s of the 3087.91s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.04%)
# 	0.9314	 = Validation score   (f1)
# 	16.58s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 3070.63s of the 3070.63s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=14, gpus=0, memory=0.06%)
# 	0.9284	 = Validation score   (f1)
# 	5.88s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 3064.01s of the 3064.01s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1 workers, per: cpus=28, gpus=0, memory=0.02%)
# 	0.9305	 = Validation score   (f1)
# 	52.0s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 3011.28s of the 3011.28s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=3, gpus=0, memory=0.08%)
# 	0.928	 = Validation score   (f1)
# 	2.96s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 3007.51s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.889, 'LightGBM_BAG_L2': 0.056, 'RandomForestEntr_BAG_L2': 0.056}
# 	0.9321	 = Validation score   (f1)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 279.55s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1141.3 rows/s (1000 batch size)
# Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# Fitting 1 L1 models ...
# Fitting model: LightGBMXT_BAG_L1_FULL ...
# 	2.88s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBM_BAG_L1_FULL ...
# 	0.51s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.36s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.31s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: CatBoost_BAG_L1_FULL ...
# 	2.18s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.28s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# 	0.28s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# No improvement since epoch 0: early stopping
# 	2.24s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	0.32s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	11.72s	 = Training   runtime
# Fitting 1 L1 models ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	1.61s	 = Training   runtime
# Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'LightGBMLarge_BAG_L1': 1.0}
# 	0.3s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMXT_BAG_L2_FULL ...
# 	0.22s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBM_BAG_L2_FULL ...
# 	0.26s	 = Training   runtime
# Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.36s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.34s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: CatBoost_BAG_L2_FULL ...
# 	0.15s	 = Training   runtime
# Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.3s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	0.29s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# 	Stopping at the best epoch learned earlier - 11.
# 	1.1s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: XGBoost_BAG_L2_FULL ...
# 	0.21s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# 	2.07s	 = Training   runtime
# Fitting 1 L2 models ...
# Fitting model: LightGBMLarge_BAG_L2_FULL ...
# 	1.38s	 = Training   runtime
# Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.889, 'LightGBM_BAG_L2': 0.056, 'RandomForestEntr_BAG_L2': 0.056}
# 	0.57s	 = Training   runtime
# Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 27.26s ... Best model: "WeightedEnsemble_L3_FULL"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20241101_083000")

# %%
# hardening_results
# Out:
#                techniques   roc_auc       f1  precision  recall
# 0  gan_gaussian_naive_vae  0.975049  0.92577   0.889606   0.965

# %%
# will return the path to the cloned predictor, identical to save_path_clone_opt
# path_clone_opt = predictor.clone_for_deployment(path='anomaly_detection')
# Out:
# Cloned TabularPredictor located in 'AutogluonModels/ag-20241101_083000' to 'anomaly_detection'.
# 	To load the cloned predictor: predictor_clone = TabularPredictor.load(path="anomaly_detection")
# Clone: Keeping minimum set of models required to predict with best model 'WeightedEnsemble_L3_FULL'...
# Deleting model LightGBMXT_BAG_L1. All files under anomaly_detection/models/LightGBMXT_BAG_L1 will be removed.
# Deleting model LightGBM_BAG_L1. All files under anomaly_detection/models/LightGBM_BAG_L1 will be removed.
# Deleting model RandomForestGini_BAG_L1. All files under anomaly_detection/models/RandomForestGini_BAG_L1 will be removed.
# Deleting model RandomForestEntr_BAG_L1. All files under anomaly_detection/models/RandomForestEntr_BAG_L1 will be removed.
# Deleting model CatBoost_BAG_L1. All files under anomaly_detection/models/CatBoost_BAG_L1 will be removed.
# Deleting model ExtraTreesGini_BAG_L1. All files under anomaly_detection/models/ExtraTreesGini_BAG_L1 will be removed.
# Deleting model ExtraTreesEntr_BAG_L1. All files under anomaly_detection/models/ExtraTreesEntr_BAG_L1 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1. All files under anomaly_detection/models/NeuralNetFastAI_BAG_L1 will be removed.
# Deleting model XGBoost_BAG_L1. All files under anomaly_detection/models/XGBoost_BAG_L1 will be removed.
# Deleting model NeuralNetTorch_BAG_L1. All files under anomaly_detection/models/NeuralNetTorch_BAG_L1 will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under anomaly_detection/models/LightGBMLarge_BAG_L1 will be removed.
# Deleting model WeightedEnsemble_L2. All files under anomaly_detection/models/WeightedEnsemble_L2 will be removed.
# Deleting model LightGBMXT_BAG_L2. All files under anomaly_detection/models/LightGBMXT_BAG_L2 will be removed.
# Deleting model LightGBM_BAG_L2. All files under anomaly_detection/models/LightGBM_BAG_L2 will be removed.
# Deleting model RandomForestGini_BAG_L2. All files under anomaly_detection/models/RandomForestGini_BAG_L2 will be removed.
# Deleting model RandomForestEntr_BAG_L2. All files under anomaly_detection/models/RandomForestEntr_BAG_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under anomaly_detection/models/CatBoost_BAG_L2 will be removed.
# Deleting model ExtraTreesGini_BAG_L2. All files under anomaly_detection/models/ExtraTreesGini_BAG_L2 will be removed.
# Deleting model ExtraTreesEntr_BAG_L2. All files under anomaly_detection/models/ExtraTreesEntr_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under anomaly_detection/models/NeuralNetFastAI_BAG_L2 will be removed.
# Deleting model XGBoost_BAG_L2. All files under anomaly_detection/models/XGBoost_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_BAG_L2. All files under anomaly_detection/models/NeuralNetTorch_BAG_L2 will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under anomaly_detection/models/LightGBMLarge_BAG_L2 will be removed.
# Deleting model WeightedEnsemble_L3. All files under anomaly_detection/models/WeightedEnsemble_L3 will be removed.
# Deleting model WeightedEnsemble_L2_FULL. All files under anomaly_detection/models/WeightedEnsemble_L2_FULL will be removed.
# Deleting model LightGBMXT_BAG_L2_FULL. All files under anomaly_detection/models/LightGBMXT_BAG_L2_FULL will be removed.
# Deleting model RandomForestGini_BAG_L2_FULL. All files under anomaly_detection/models/RandomForestGini_BAG_L2_FULL will be removed.
# Deleting model CatBoost_BAG_L2_FULL. All files under anomaly_detection/models/CatBoost_BAG_L2_FULL will be removed.
# Deleting model ExtraTreesGini_BAG_L2_FULL. All files under anomaly_detection/models/ExtraTreesGini_BAG_L2_FULL will be removed.
# Deleting model ExtraTreesEntr_BAG_L2_FULL. All files under anomaly_detection/models/ExtraTreesEntr_BAG_L2_FULL will be removed.
# Deleting model XGBoost_BAG_L2_FULL. All files under anomaly_detection/models/XGBoost_BAG_L2_FULL will be removed.
# Deleting model NeuralNetTorch_BAG_L2_FULL. All files under anomaly_detection/models/NeuralNetTorch_BAG_L2_FULL will be removed.
# Deleting model LightGBMLarge_BAG_L2_FULL. All files under anomaly_detection/models/LightGBMLarge_BAG_L2_FULL will be removed.
# Clone: Removing artifacts unnecessary for prediction. NOTE: Clone can no longer fit new models, and most functionality except for predict and predict_proba will no longer work

# %%
# predictor_clone_opt = TabularPredictor.load(path='anomaly_detection')

# %%
# predictor_clone_opt.leaderboard(test_data)
# Out:
#                            model  score_test score_val eval_metric  \
# 0   RandomForestEntr_BAG_L2_FULL    0.981346      None          f1
# 1           LightGBM_BAG_L2_FULL    0.980177      None          f1
# 2       WeightedEnsemble_L3_FULL    0.979982      None          f1
# 3    NeuralNetFastAI_BAG_L2_FULL    0.979397      None          f1
# 4           CatBoost_BAG_L1_FULL    0.974096      None          f1
# 5      LightGBMLarge_BAG_L1_FULL    0.972976      None          f1
# 6           LightGBM_BAG_L1_FULL    0.971855      None          f1
# 7            XGBoost_BAG_L1_FULL    0.969072      None          f1
# 8   RandomForestEntr_BAG_L1_FULL    0.967675      None          f1
# 9   RandomForestGini_BAG_L1_FULL    0.967609      None          f1
# 10        LightGBMXT_BAG_L1_FULL    0.967209      None          f1
# 11    NeuralNetTorch_BAG_L1_FULL    0.962387      None          f1
# 12    ExtraTreesEntr_BAG_L1_FULL    0.959417      None          f1
# 13    ExtraTreesGini_BAG_L1_FULL    0.958605      None          f1
# 14   NeuralNetFastAI_BAG_L1_FULL    0.846265      None          f1
#
#     pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  \
# 0         0.459893            NaN  23.031729                 0.052717
# 1         0.411256            NaN  22.954014                 0.004080
# 2         0.506121            NaN  24.965887                 0.000977
# 3         0.448347            NaN  23.796657                 0.041171
# 4         0.003313            NaN   2.182069                 0.003313
# 5         0.024953            NaN   1.605155                 0.024953
# 6         0.009790            NaN   0.514354                 0.009790
# 7         0.015781            NaN   0.322650                 0.015781
# 8         0.054036       0.106759   0.313069                 0.054036
# 9         0.054112       0.110307   0.358135                 0.054112
# 10        0.062712            NaN   2.881619                 0.062712
# 11        0.040446            NaN  11.717933                 0.040446
# 12        0.052981       0.100728   0.282299                 0.052981
# 13        0.051664       0.098676   0.280749                 0.051664
# 14        0.037388            NaN   2.236092                 0.037388
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.096832           0.337605            2       True
# 1                      NaN           0.259889            2       True
# 2                      NaN           0.571736            3       True
# 3                      NaN           1.102532            2       True
# 4                      NaN           2.182069            1       True
# 5                      NaN           1.605155            1       True
# 6                      NaN           0.514354            1       True
# 7                      NaN           0.322650            1       True
# 8                 0.106759           0.313069            1       True
# 9                 0.110307           0.358135            1       True
# 10                     NaN           2.881619            1       True
# 11                     NaN          11.717933            1       True
# 12                0.100728           0.282299            1       True
# 13                0.098676           0.280749            1       True
# 14                     NaN           2.236092            1       True
#
#     fit_order
# 0          13
# 1          12
# 2          15
# 3          14
# 4           5
# 5          11
# 6           2
# 7           9
# 8           4
# 9           3
# 10          1
# 11         10
# 12          7
# 13          6
# 14          8

# %%
# size_original = predictor.disk_usage()
# size_opt = predictor_clone_opt.disk_usage()
# print(f'Size Original:  {size_original} bytes')
# print(f'Size Optimized: {size_opt} bytes')
# print(f'Optimized predictor achieved a {round((1 - (size_opt/size_original)) * 100, 1)}% reduction in disk usage.')
# Out:
# Size Original:  353087345 bytes
# Size Optimized: 115663471 bytes
# Optimized predictor achieved a 67.2% reduction in disk usage.
# *** SIGTERM received at time=1730452320 on cpu 13 ***
# PC: @     0x7aa94eb2a042  (unknown)  epoll_wait
#     @     0x7aa94ea45320  876074928  (unknown)
#     @     0x7aa94f103c52  (unknown)  select_epoll_poll_impl
# [2024-11-01 20:12:00,674 E 1470 1470] logging.cc:361: *** SIGTERM received at time=1730452320 on cpu 13 ***
# [2024-11-01 20:12:00,674 E 1470 1470] logging.cc:361: PC: @     0x7aa94eb2a042  (unknown)  epoll_wait
# [2024-11-01 20:12:00,675 E 1470 1470] logging.cc:361:     @     0x7aa94ea45320  876074928  (unknown)
# [2024-11-01 20:12:00,675 E 1470 1470] logging.cc:361:     @     0x7aa94f103c52  (unknown)  select_epoll_poll_impl
